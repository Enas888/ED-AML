# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 85.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 754.4 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 36.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from google.colab import files

# Upload ZIP files
print("Upload training ZIP:")
files.upload()  # Select cell_hue.zip
print("\nUpload test ZIP:")
files.upload()  # Select test_cell_hue.zip
# Out:
# Upload training ZIP:
#      <input type="file" id="files-c18ff635-293f-4cf7-bbf6-8c8a914dc0ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c18ff635-293f-4cf7-bbf6-8c8a914dc0ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
from ultralytics import YOLO
import os
import zipfile
from pathlib import Path
from google.colab import drive
from IPython.display import Image  

# 1. Mount Google Drive (if your files are there)
# drive.mount('/content/drive')

# 2. Extract ZIP files using !unzip command
print("Extracting training data...")
# !unzip '/content/cell_hue.zip'

print("\nExtracting test data...")
# !unzip '/content/test_cell_hue.zip'

# # Verify extraction
print("\nVerifying extraction...")
# !ls -la '/content/cell_hue'
# !ls -la '/content/test_cell_hue'

# 4. Training Configuration
model = YOLO("yolo12-cls.yaml")

# Train using the extracted folders
results = model.train(
    data='/content/cell_hue',  # Contains train/val subfolders
    epochs=40,
    imgsz=224,
    batch=32,
    name='cell_hue_classification'
)

display(Image("/content/runs/classify/cell_hue_classification/confusion_matrix.png", width=600))
display(Image("/content/runs/classify/cell_hue_classification/results.png", width=600))

# Load your trained model (replace with your actual best model path)
model = YOLO('/content/runs/classify/cell_hue_classification/weights/best.pt')

# Predict on test set
test_results = model.val(
    source='/content/test_cell_hue',  # Your test directory
    save=True,                       # Save predictions
    save_txt=True,                   # Save class labels
    imgsz=224,                       # Match training size
    conf=0.5                         # Confidence threshold
)
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: cell_hue/train/basophil/BA_190505.jpg
#   inflating: cell_hue/train/basophil/BA_191120.jpg
#   inflating: cell_hue/train/basophil/BA_193863.jpg
#   inflating: cell_hue/train/basophil/BA_196807.jpg
#   inflating: cell_hue/train/basophil/BA_198565.jpg
#   inflating: cell_hue/train/basophil/BA_199179.jpg
#   inflating: cell_hue/train/basophil/BA_200697.jpg
#   inflating: cell_hue/train/basophil/BA_200989.jpg
#   inflating: cell_hue/train/basophil/BA_20201.jpg
#   inflating: cell_hue/train/basophil/BA_204774.jpg
#   inflating: cell_hue/train/basophil/BA_206112.jpg
#   inflating: cell_hue/train/basophil/BA_206130.jpg
#   inflating: cell_hue/train/basophil/BA_208485.jpg
#   inflating: cell_hue/train/basophil/BA_209608.jpg
#   inflating: cell_hue/train/basophil/BA_212732.jpg
#   inflating: cell_hue/train/basophil/BA_212748.jpg
#   inflating: cell_hue/train/basophil/BA_21413.jpg
# ...

# %%
from ultralytics import YOLO
import os
import zipfile
from pathlib import Path
from google.colab import drive
from IPython.display import Image  

# 2. Extract ZIP files using !unzip command
print("Extracting training data...")
# !unzip '/content/cell_otsu_dilation.zip'

print("\nExtracting test data...")
# !unzip '/content/test_cell_otsu_dilation.zip'

# Verify extraction
print("\nVerifying extraction...")
# !ls -la '/content/cell_otsu_dilation'
# !ls -la '/content/test_cell_otsu_dilation'

# 4. Training Configuration
model = YOLO("yolo12-cls.yaml")

# Train using the extracted folders
results = model.train(
    data='/content/cell_otsu_dilation',  # Contains train/val subfolders
    epochs=40,
    imgsz=224,
    batch=32,
    name='cell_otsu_dilation_classification'
)

display(Image("/content/runs/classify/cell_otsu_dilation_classification/confusion_matrix.png", width=600))
display(Image("/content/runs/classify/cell_otsu_dilation_classification/results.png", width=600))

# Load your trained model (replace with your actual best model path)
model = YOLO('/content/runs/classify/cell_otsu_dilation_classification/weights/best.pt')

# Predict on test set
test_results = model.val(
    source='/content/test_cell_otsu_dilation',  # Your test directory
    save=True,                       # Save predictions
    save_txt=True,                   # Save class labels
    imgsz=224,                       # Match training size
    conf=0.5                         # Confidence threshold
)
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: cell_otsu_dilation/train/basophil/BA_190505.jpg
#   inflating: cell_otsu_dilation/train/basophil/BA_191120.jpg
#   inflating: cell_otsu_dilation/train/basophil/BA_193863.jpg
#   inflating: cell_otsu_dilation/train/basophil/BA_196807.jpg
#   inflating: cell_otsu_dilation/train/basophil/BA_198565.jpg
#   inflating: cell_otsu_dilation/train/basophil/BA_199179.jpg
#   inflating: cell_otsu_dilation/train/basophil/BA_200697.jpg
#   inflating: cell_otsu_dilation/train/basophil/BA_200989.jpg
#   inflating: cell_otsu_dilation/train/basophil/BA_20201.jpg
#   inflating: cell_otsu_dilation/train/basophil/BA_204774.jpg
#   inflating: cell_otsu_dilation/train/basophil/BA_206112.jpg
#   inflating: cell_otsu_dilation/train/basophil/BA_206130.jpg
#   inflating: cell_otsu_dilation/train/basophil/BA_208485.jpg
#   inflating: cell_otsu_dilation/train/basophil/BA_209608.jpg
#   inflating: cell_otsu_dilation/train/basophil/BA_212732.jpg
# ...

# %%
from ultralytics import YOLO
import os
import zipfile
from pathlib import Path
from google.colab import drive
from IPython.display import Image

# 2. Extract ZIP files using !unzip command
print("Extracting training data...")
# !unzip '/content/nucleus_hue_channel.zip'

print("\nExtracting test data...")
# !unzip '/content/test_nucleus_hue_channel.zip'

# Verify extraction
print("\nVerifying extraction...")
# !ls -la '/content/nucleus_hue_channel'
# !ls -la '/content/test_nucleus_hue_channel'

# 4. Training Configuration
model = YOLO("yolo12-cls.yaml")

# Train using the extracted folders
results = model.train(
    data='/content/nucleus_hue_channel',
    epochs=40,
    imgsz=224,
    batch=32,
    name='nucleus_hue_channel_classification'
)

display(Image("/content/runs/classify/nucleus_hue_channel_classification/confusion_matrix.png", width=600))
display(Image("/content/runs/classify/nucleus_hue_channel_classification/results.png", width=600))

# Load trained model
model = YOLO('/content/runs/classify/nucleus_hue_channel_classification/weights/best.pt')

# Predict on test set
test_results = model.val(
    source='/content/test_nucleus_hue_channel',
    save=True,
    save_txt=True,
    imgsz=224,
    conf=0.5
)
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: nucleus_hue_channel/train/basophil/BA_190505.jpg
#   inflating: nucleus_hue_channel/train/basophil/BA_191120.jpg
#   inflating: nucleus_hue_channel/train/basophil/BA_193863.jpg
#   inflating: nucleus_hue_channel/train/basophil/BA_196807.jpg
#   inflating: nucleus_hue_channel/train/basophil/BA_198565.jpg
#   inflating: nucleus_hue_channel/train/basophil/BA_199179.jpg
#   inflating: nucleus_hue_channel/train/basophil/BA_200697.jpg
#   inflating: nucleus_hue_channel/train/basophil/BA_200989.jpg
#   inflating: nucleus_hue_channel/train/basophil/BA_20201.jpg
#   inflating: nucleus_hue_channel/train/basophil/BA_204774.jpg
#   inflating: nucleus_hue_channel/train/basophil/BA_206112.jpg
#   inflating: nucleus_hue_channel/train/basophil/BA_206130.jpg
#   inflating: nucleus_hue_channel/train/basophil/BA_208485.jpg
#   inflating: nucleus_hue_channel/train/basophil/BA_209608.jpg
# ...

# %%
from ultralytics import YOLO
import os
import zipfile
from pathlib import Path
from google.colab import drive
from IPython.display import Image

# 2. Extract ZIP files using !unzip command
print("Extracting training data...")
# !unzip '/content/nucleus_otsu.zip'

print("\nExtracting test data...")
# !unzip '/content/test_nucleus_otsu.zip'

# Verify extraction
print("\nVerifying extraction...")
# !ls -la '/content/nucleus_otsu'
# !ls -la '/content/test_nucleus_otsu'

# 4. Training Configuration
model = YOLO("yolo12-cls.yaml")

# Train using the extracted folders
results = model.train(
    data='/content/nucleus_otsu',
    epochs=40,
    imgsz=224,
    batch=32,
    name='nucleus_otsu_classification'
)

display(Image("/content/runs/classify/nucleus_otsu_classification/confusion_matrix.png", width=600))
display(Image("/content/runs/classify/nucleus_otsu_classification/results.png", width=600))

# Load trained model
model = YOLO('/content/runs/classify/nucleus_otsu_classification/weights/best.pt')

# Predict on test set
test_results = model.val(
    source='/content/test_nucleus_otsu',
    save=True,
    save_txt=True,
    imgsz=224,
    conf=0.5
)
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: nucleus_otsu/train/basophil/BA_190505.jpg
#   inflating: nucleus_otsu/train/basophil/BA_191120.jpg
#   inflating: nucleus_otsu/train/basophil/BA_193863.jpg
#   inflating: nucleus_otsu/train/basophil/BA_196807.jpg
#   inflating: nucleus_otsu/train/basophil/BA_198565.jpg
#   inflating: nucleus_otsu/train/basophil/BA_199179.jpg
#   inflating: nucleus_otsu/train/basophil/BA_200697.jpg
#   inflating: nucleus_otsu/train/basophil/BA_200989.jpg
#   inflating: nucleus_otsu/train/basophil/BA_20201.jpg
#   inflating: nucleus_otsu/train/basophil/BA_204774.jpg
#   inflating: nucleus_otsu/train/basophil/BA_206112.jpg
#   inflating: nucleus_otsu/train/basophil/BA_206130.jpg
#   inflating: nucleus_otsu/train/basophil/BA_208485.jpg
#   inflating: nucleus_otsu/train/basophil/BA_209608.jpg
#   inflating: nucleus_otsu/train/basophil/BA_212732.jpg
#   inflating: nucleus_otsu/train/basophil/BA_212748.jpg
# ...

# %% [markdown]
# # Download results:

# %%
from google.colab import files
import os

# 1. Define experiment name and paths
exp_name = "cell_hue_classification"
results_dir = f"/content/runs/classify/{exp_name}"
test_acc = test_results.top1  # Get the test accuracy from your validation results

# 2. Save test accuracy to a text file
with open(f"{exp_name}_results.txt", "w") as f:
    f.write(f"Experiment Name: {exp_name}\n")
    f.write(f"Test Accuracy: {test_acc:.4f}\n")
    f.write(f"Top-5 Accuracy: {test_results.top5:.4f}\n")

# 3. Download the text file and visualizations
files.download(f"{exp_name}_results.txt")  # Download the text results
files.download(f"{results_dir}/confusion_matrix.png")  # Download confusion matrix
files.download(f"{results_dir}/results.png")  # Download training results plot

# 4. (Optional) Zip all results for easier download
# !zip -r {exp_name}_results.zip {exp_name}_results.txt {results_dir}/confusion_matrix.png {results_dir}/results.png
files.download(f"{exp_name}_results.zip")  # Download all as a single zip



from google.colab import files
import os

# 1. Define experiment name and paths
exp_name = "cell_otsu_dilation_classification"
results_dir = f"/content/runs/classify/{exp_name}"
test_acc = test_results.top1  # Get the test accuracy from your validation results

# 2. Save test accuracy to a text file
with open(f"{exp_name}_results.txt", "w") as f:
    f.write(f"Experiment Name: {exp_name}\n")
    f.write(f"Test Accuracy: {test_acc:.4f}\n")
    f.write(f"Top-5 Accuracy: {test_results.top5:.4f}\n")

# 3. Download the text file and visualizations
files.download(f"{exp_name}_results.txt")  # Download the text results
files.download(f"{results_dir}/confusion_matrix.png")  # Download confusion matrix
files.download(f"{results_dir}/results.png")  # Download training results plot

# 4. (Optional) Zip all results for easier download
# !zip -r {exp_name}_results.zip {exp_name}_results.txt {results_dir}/confusion_matrix.png {results_dir}/results.png
files.download(f"{exp_name}_results.zip")  # Download all as a single zip


from google.colab import files
import os

# 1. Define experiment name and paths
exp_name = "nucleus_hue_channel_classification"
results_dir = f"/content/runs/classify/{exp_name}"
test_acc = test_results.top1  # Get the test accuracy from your validation results

# 2. Save test accuracy to a text file
with open(f"{exp_name}_results.txt", "w") as f:
    f.write(f"Experiment Name: {exp_name}\n")
    f.write(f"Test Accuracy: {test_acc:.4f}\n")
    f.write(f"Top-5 Accuracy: {test_results.top5:.4f}\n")

# 3. Download the text file and visualizations
files.download(f"{exp_name}_results.txt")  # Download the text results
files.download(f"{results_dir}/confusion_matrix.png")  # Download confusion matrix
files.download(f"{results_dir}/results.png")  # Download training results plot

# 4. (Optional) Zip all results for easier download
# !zip -r {exp_name}_results.zip {exp_name}_results.txt {results_dir}/confusion_matrix.png {results_dir}/results.png
files.download(f"{exp_name}_results.zip")  # Download all as a single zip



from google.colab import files
import os

# 1. Define experiment name and paths
exp_name = "nucleus_otsu_classification"
results_dir = f"/content/runs/classify/{exp_name}"
test_acc = test_results.top1  # Get the test accuracy from your validation results

# 2. Save test accuracy to a text file
with open(f"{exp_name}_results.txt", "w") as f:
    f.write(f"Experiment Name: {exp_name}\n")
    f.write(f"Test Accuracy: {test_acc:.4f}\n")
    f.write(f"Top-5 Accuracy: {test_results.top5:.4f}\n")

# 3. Download the text file and visualizations
files.download(f"{exp_name}_results.txt")  # Download the text results
files.download(f"{results_dir}/confusion_matrix.png")  # Download confusion matrix
files.download(f"{results_dir}/results.png")  # Download training results plot

# 4. (Optional) Zip all results for easier download
# !zip -r {exp_name}_results.zip {exp_name}_results.txt {results_dir}/confusion_matrix.png {results_dir}/results.png
files.download(f"{exp_name}_results.zip")  # Download all as a single zip
# Out:
#   adding: nucleus_hue_channel_classification_results.txt (deflated 9%)
#   adding: content/runs/classify/nucleus_hue_channel_classification/confusion_matrix.png (deflated 26%)
#   adding: content/runs/classify/nucleus_hue_channel_classification/results.png (deflated 9%)
#   adding: nucleus_otsu_classification_results.txt (deflated 10%)
#   adding: content/runs/classify/nucleus_otsu_classification/confusion_matrix.png (deflated 25%)
#   adding: content/runs/classify/nucleus_otsu_classification/results.png (deflated 9%)
